# %% [markdown]
# ## Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Install Package

# %% [markdown]
# ## Train

# %%
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/transformer')

# %%
# !pip install transformers

# %%
# !python3 "/content/drive/My Drive/Colab Notebooks/transformer/train_translation.py"
# Out:
# 100% 200000/200000 [02:22<00:00, 1407.79it/s]
# Epoch-44 Iterator: |          | 39501/? [07:33<00:00, 87.19it/s, | epoch  44 | 22499/22500 batches | lr 0.08 | ms/batch 72.30 | loss  2.60 | ppl    13.40]
# -----------------------------------------------------------------------------------------
# | end of epoch  44 | time: 505.10s | valid loss  2.81 | valid ppl    16.56
# -----------------------------------------------------------------------------------------
# Epoch-45 Iterator: 100% 22500/22500 [31:10<00:00, 12.03it/s, | epoch  45 | 22499/22500 batches | lr 0.08 | ms/batch 72.82 | loss  2.89 | ppl    17.96]
# -----------------------------------------------------------------------------------------
# | end of epoch  45 | time: 1923.19s | valid loss  2.79 | valid ppl    16.23
# -----------------------------------------------------------------------------------------
# ...
