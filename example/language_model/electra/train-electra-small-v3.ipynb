# %% [markdown]
# ## Google Drive

# %%
  from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Install Package

# %% [markdown]
# ## Train

# %%
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/transformer-electra')

# %%
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 2.2MB 5.6MB/s
# ...
#      |████████████████████████████████| 3.3MB 35.4MB/s
# ...
#      |████████████████████████████████| 870kB 38.2MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.44-cp37-none-any.whl size=886084 sha256=6ce49518dfa415473504a6d7e11f3c93692d75915559856bbdc8e2282930bfca
#   Stored in directory: /root/.cache/pip/wheels/3e/fb/c0/13ab4d63d537658f448366744654323077c4d90069b6512f3c
# Successfully built sacremoses
# ...

# %%
# %%writefile setup.sh
#
# git clone https://github.com/NVIDIA/apex
# cd apex
# pip install -v --no-cache-dir ./
# Out:
# Writing setup.sh

# %%
# !sh setup.sh
# Out:
# Cloning into 'apex'...
# remote: Enumerating objects: 26, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 7939 (delta 5), reused 12 (delta 0), pack-reused 7913
# Receiving objects: 100% (7939/7939), 14.03 MiB | 22.23 MiB/s, done.
# Resolving deltas: 100% (5404/5404), done.
# Created temporary directory: /tmp/pip-ephem-wheel-cache-xmtzjc98
# Created temporary directory: /tmp/pip-req-tracker-zmxey5qd
# Created requirements tracker '/tmp/pip-req-tracker-zmxey5qd'
# Created temporary directory: /tmp/pip-install-9ck0m222
# Processing /content/apex
#   Created temporary directory: /tmp/pip-req-build-agrjgb22
#   Added file:///content/apex to build tracker '/tmp/pip-req-tracker-zmxey5qd'
#     Running setup.py (path:/tmp/pip-req-build-agrjgb22/setup.py) egg_info for package from file:///content/apex
#     Running command python setup.py egg_info
#
#
#     torch.__version__  = 1.8.1+cu101
#
#
#     running egg_info
# ...

# %%
# !python3 "/content/drive/My Drive/Colab Notebooks/transformer-electra/example/language_model/electra/run_pretraining_small_v3.py"
# Out:
# 2021-04-11 04:33:54.352410: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Selected optimization level O2:  FP16 training with FP32 batchnorm and FP32 master weights.
#
# Defaults for this optimization level are:
# enabled                : True
# opt_level              : O2
# cast_model_type        : torch.float16
# patch_torch_functions  : False
# keep_batchnorm_fp32    : True
# master_weights         : True
# loss_scale             : dynamic
# Processing user overrides (additional kwargs that are not None)...
# After processing overrides, optimization options are:
# enabled                : True
# opt_level              : O2
# cast_model_type        : torch.float16
# patch_torch_functions  : False
# keep_batchnorm_fp32    : True
# master_weights         : True
# loss_scale             : dynamic
# ...
