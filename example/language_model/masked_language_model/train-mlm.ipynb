# %% [markdown]
# ## Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Install Package

# %% [markdown]
# ## Train

# %%
import sys
sys.path.append('/content/drive/My Drive/Colab Notebooks/transformer')

# %%
# !pip install transformers
# !pip install fairseq
# Out:
# ...
#      |████████████████████████████████| 1.9MB 13.2MB/s
# ...
#      |████████████████████████████████| 890kB 48.7MB/s
# ...
#      |████████████████████████████████| 3.2MB 41.2MB/s
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp37-none-any.whl size=893262 sha256=0e1619429180dbd75c900b5b999d542c17713a8cc8ca78a5a28beb10a49c0e7d
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# ...
#      |████████████████████████████████| 1.7MB 14.3MB/s
# ...
#      |████████████████████████████████| 71kB 5.9MB/s
# ...
#      |████████████████████████████████| 133kB 54.1MB/s
# ...
#      |████████████████████████████████| 112kB 53.9MB/s
# ...
#      |████████████████████████████████| 645kB 54.3MB/s
# ...
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.8-cp37-none-any.whl size=141231 sha256=22eceb36b19347b1e274169ec1a815cd92438114b59ab2f3d931b47f421357d0
# ...

# %%
# !python3 "/content/drive/My Drive/Colab Notebooks/transformer/example/language_model/masked_language_model/run_pretraining.py"
# Out:
# Epoch-27 Iterator: 100% 8113/8113 [33:41<00:00,  4.01it/s, 2021-03-03 15:35:13.451400 | Train Loss: 2.146580696105957 | Steps: 227164]
# Evaluating: 100% 902/902 [04:51<00:00,  3.09it/s]
# Epoch-28 Iterator: 100% 8113/8113 [1:15:29<00:00,  1.79it/s, 2021-03-03 16:55:34.194215 | Train Loss: 1.8402827978134155 | Steps: 235277]
# Evaluating: 100% 902/902 [04:52<00:00,  3.08it/s]
# Epoch-29 Iterator: 100% 8113/8113 [1:15:22<00:00,  1.79it/s, 2021-03-03 18:15:49.693623 | Train Loss: 2.026031017303467 | Steps: 243390]
# Evaluating: 100% 902/902 [04:44<00:00,  3.17it/s]
# Epoch-30 Iterator: 100% 8113/8113 [1:15:25<00:00,  1.79it/s, 2021-03-03 19:35:59.773260 | Train Loss: 1.7944914102554321 | Steps: 251503]
# Evaluating: 100% 902/902 [04:53<00:00,  3.08it/s]
# Epoch-31 Iterator: 100% 8113/8113 [1:15:37<00:00,  1.79it/s, 2021-03-03 20:56:30.333348 | Train Loss: 1.9062824249267578 | Steps: 259616]
# Evaluating: 100% 902/902 [04:52<00:00,  3.09it/s]
# ...
